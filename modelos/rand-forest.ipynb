# %%
# Importar librerías para análisis y manipulación de datos
import pandas as pd
import numpy as np

# Visualización
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Preparación de datos y partición
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# Modelo Random Forest
from sklearn.ensemble import RandomForestRegressor

# Evaluación del modelo
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, make_scorer, r2_score

# %%
df = pd.read_csv('/kaggle/input/viviendas-modelos/viviendas_model.csv')

# %%
# df = df.drop([
#     'Paro hombre edad < 25',
#     'Paro hombre edad >=45',
#     'Paro mujer edad < 25',
#     'Paro mujer edad 25 -45 ',
#     'Paro Agricultura',
#     'Paro Industria',
#     'Paro construccion',
#     'Paro Servicios',
#     'Paro Sin empleo Anterior',
#     'Mediana de la renta por unidad de consumo',
#     'Renta bruta media por persona',
#     'Renta neta media por persona ',
#     'Renta bruta media por hogar',
#     'total Paro Registrado']
#         ,axis=1)

# %%
# Verificar si hay datos faltantes
def check_missing_data(df):
    hay_nan = df.isnull().values.any()
    print(f"¿Hay algún NaN en el DataFrame? {hay_nan}")

    nan_por_columna = df.isnull().sum()
    print("Cantidad de NaN por columna:\n", nan_por_columna)

    filas_con_nan = df[df.isnull().any(axis=1)]
    print("Filas que contienen NaN:\n", filas_con_nan)

    return hay_nan, nan_por_columna, filas_con_nan

# %%
hay_nan, nan_por_columna, filas_con_nan = check_missing_data(df)
if hay_nan:
    df = df.dropna()
hay_nan, nan_por_columna, filas_con_nan = check_missing_data(df)
# Out:
# ¿Hay algún NaN en el DataFrame? True
# Cantidad de NaN por columna:
#  Caracteristicas                              0
# Habitaciones                                 0
# Aseos                                        0
# Terraza                                      0
# Piscina                                      0
# Garaje                                       0
# Precio                                       0
# Metros                                       0
# CodigoPostal                                 1
# Latitud                                      0
# Longitud                                     0
# Mediana de la renta por unidad de consumo    0
# Renta bruta media por hogar                  0
# Renta bruta media por persona                0
# Renta neta media por persona                 0
# total Paro Registrado                        0
# Paro hombre edad < 25                        0
# Paro hombre edad >=45                        0
# Paro mujer edad < 25                         0
# Paro mujer edad 25 -45                       0
# Paro Agricultura                             0
# Paro Industria                               0
# Paro construccion                            0
# Paro Servicios                               0
# Paro Sin empleo Anterior                     0
# precio_por_metro                             0
# precio_medio_m2                              0
# dtype: int64
# Filas que contienen NaN:
#         Caracteristicas  Habitaciones  Aseos  Terraza  Piscina  Garaje  \
# 48472                5           2.0    2.0        1        0       0
#
#          Precio  Metros  CodigoPostal  Latitud  ...  Paro hombre edad >=45  \
# 48472  219000.0    86.0           NaN    15893  ...                   39.0
#
#        Paro mujer edad < 25  Paro mujer edad 25 -45   Paro Agricultura  \
# 48472                   5.0                     36.0               5.0
#
#        Paro Industria  Paro construccion  Paro Servicios  \
# 48472            10.0               13.0           128.0
#
#        Paro Sin empleo Anterior  precio_por_metro  precio_medio_m2
# 48472                      10.0       2546.511628      3775.926841
#
# [1 rows x 27 columns]
# ¿Hay algún NaN en el DataFrame? False
# Cantidad de NaN por columna:
#  Caracteristicas                              0
# Habitaciones                                 0
# Aseos                                        0
# Terraza                                      0
# Piscina                                      0
# Garaje                                       0
# Precio                                       0
# Metros                                       0
# CodigoPostal                                 0
# Latitud                                      0
# Longitud                                     0
# Mediana de la renta por unidad de consumo    0
# Renta bruta media por hogar                  0
# Renta bruta media por persona                0
# Renta neta media por persona                 0
# total Paro Registrado                        0
# Paro hombre edad < 25                        0
# Paro hombre edad >=45                        0
# Paro mujer edad < 25                         0
# Paro mujer edad 25 -45                       0
# Paro Agricultura                             0
# Paro Industria                               0
# Paro construccion                            0
# Paro Servicios                               0
# Paro Sin empleo Anterior                     0
# precio_por_metro                             0
# precio_medio_m2                              0
# dtype: int64
# Filas que contienen NaN:
#  Empty DataFrame
# Columns: [Caracteristicas, Habitaciones, Aseos, Terraza, Piscina, Garaje, Precio, Metros, CodigoPostal, Latitud, Longitud, Mediana de la renta por unidad de consumo, Renta bruta media por hogar, Renta bruta media por persona, Renta neta media por persona , total Paro Registrado, Paro hombre edad < 25, Paro hombre edad >=45, Paro mujer edad < 25, Paro mujer edad 25 -45 , Paro Agricultura, Paro Industria, Paro construccion, Paro Servicios, Paro Sin empleo Anterior, precio_por_metro, precio_medio_m2]
# Index: []
#
# [0 rows x 27 columns]

# %%
# Características y etiqueta
X = df.drop('Precio', axis=1)
y = df['Precio']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=101)

# Guardar los índices originales de X_test antes de escalar
X_test_indices = X_test.index

# Escalado de características
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_test_scaled_df = pd.DataFrame(X_test_scaled, index=X_test_indices, columns=X_test.columns)

# %%
# Crear el modelo Random Forest
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
# Crear un KFold para la validación cruzada
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Evaluar el modelo utilizando la validación cruzada
cv_results = cross_val_score(rf_model, X_train_scaled, y_train, cv=kf, scoring='neg_mean_squared_error')

# Calcular la media y la desviación estándar del MSE
mean_mse = np.mean(np.abs(cv_results))
std_mse = np.std(cv_results)

print(f'Mean MSE: {mean_mse}')
print(f'Standard Deviation of MSE: {std_mse}')
# Out:
# Mean MSE: 29960295.477578282
# Standard Deviation of MSE: 6252974.391009539

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 10], 
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Crear el GridSearchCV
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=kf, scoring='neg_mean_squared_error', verbose=2, n_jobs=-1)

# Ajustar el GridSearchCV
grid_search.fit(X_train_scaled, y_train)

# Mejor combinación de hiperparámetros
best_params = grid_search.best_params_
print(f'Best Parameters: {best_params}')

# Evaluar el mejor modelo
best_rf_model = grid_search.best_estimator_

# Evaluar en el conjunto de prueba
best_test_predictions = best_rf_model.predict(X_test_scaled)
best_test_mse = mean_squared_error(y_test, best_test_predictions)
best_test_rmse = np.sqrt(best_test_mse)

print(f'Best Test MSE: {best_test_mse}')
print(f'Best Test RMSE: {best_test_rmse}')
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   3.7s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  17.1s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  15.4s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   7.6s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  14.6s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   3.7s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.9s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  14.8s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   3.7s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   3.7s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   4.0s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   7.7s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  14.8s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   3.7s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   3.7s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  14.8s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  15.1s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   7.5s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  14.8s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   3.7s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   4.0s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   7.4s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  14.8s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   3.7s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   3.7s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   4.2s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   7.4s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  14.8s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   3.7s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   4.1s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   7.5s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   7.3s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  14.9s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   6.2s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  11.8s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  24.2s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  24.0s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.9s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  23.6s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   5.9s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.8s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  12.1s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  23.4s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   5.9s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.3s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  23.7s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  23.5s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12

# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  10.6s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  21.4s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   5.2s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   5.3s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.2s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  21.1s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  21.5s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  10.5s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  21.6s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   5.3s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   5.3s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  11.2s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  21.1s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   5.2s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   5.8s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  10.6s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  10.5s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  21.8s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   5.3s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  10.6s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  21.7s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  21.4s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.6s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  21.5s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   5.3s
# ...
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=  11.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  22.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  22.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  44.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=  12.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  22.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  45.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  45.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  23.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  45.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=  11.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  22.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  22.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  44.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=  11.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  22.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  45.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  44.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  23.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  44.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=  11.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  21.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  22.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  44.7s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   5.5s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  10.6s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  21.8s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  21.2s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  10.9s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  21.0s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   5.3s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   5.6s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  10.6s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  21.5s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  21.3s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  10.7s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  21.2s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   5.3s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   5.5s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  10.6s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  21.9s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   5.4s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   5.3s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  10.6s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  11.3s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  21.3s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   5.6s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  11.2s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  21.7s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  21.2s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  10.9s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  21.0s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   5.3s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   5.7s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  10.7s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  21.4s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   8.7s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   8.5s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  17.6s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  34.9s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   8.6s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   8.4s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  17.3s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  17.2s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  34.7s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  17.3s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  34.3s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   8.5s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  17.6s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  34.3s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   8.7s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   8.9s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   8.6s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  17.1s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  34.5s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   8.7s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   8.5s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   8.6s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  17.5s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  34.4s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   8.5s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   8.5s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  17.4s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  17.0s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  34.6s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   8.8s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  17.0s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  34.1s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  34.6s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  17.5s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  34.4s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   8.5s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   9.0s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  17.1s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  34.5s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   8.5s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   8.7s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  16.9s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  17.3s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  34.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=  16.1s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  32.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  32.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=  16.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  32.3s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=  16.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=  16.3s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=  16.3s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  32.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=  16.1s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=  16.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  32.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  33.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=  16.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=  16.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  32.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  32.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=  16.1s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=  16.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  32.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=  16.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=  16.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  32.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  32.2s
# Best Parameters: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Best Test MSE: 102812409.5407006
# Best Test RMSE: 10139.645434663906

# %%
def evaluate(model, X_test, y_test):
    predictions = model.predict(X_test)
    
    r2 = r2_score(y_test, predictions)
    mae = mean_absolute_error(y_test, predictions)
    mse = mean_squared_error(y_test, predictions)
    
    print(f'R2: {r2}')
    print(f'MAE: {mae}')
    print(f'MSE: {mse}')
    
    # Grafica de la dispersión y la línea de regresión
    plt.figure(figsize=(10, 6))
    plt.scatter(y_test, predictions, color='blue', alpha=0.5)
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', lw=2)
    plt.xlabel('Valores Reales')
    plt.ylabel('Valores Predichos')
    plt.title('Valores Reales vs. Valores Predichos')
    plt.grid(True)
    plt.savefig('/kaggle/working/regression_plot.png')
    plt.show()

# %%
evaluate(best_rf_model, X_test_scaled, y_test)
# Out:
# R2: 0.9977686650459057
# MAE: 2702.04594427647
# MSE: 102812409.5407006

# %%
# Seleccionar aleatoriamente un inmueble del conjunto de prueba
random_inmueble_index = np.random.choice(X_test_indices)
random_inmueble = X_test_scaled_df.loc[random_inmueble_index].values.reshape(1, -1)
precio_predicho = best_rf_model.predict(random_inmueble)

precio_real = y_test.loc[random_inmueble_index]

# Imprimir el precio real y el precio predicho
print(f'El precio real del inmueble seleccionado aleatoriamente es: {precio_real}')
print(f'El precio predicho del inmueble seleccionado aleatoriamente es: {precio_predicho[0]}')
# Out:
# El precio real del inmueble seleccionado aleatoriamente es: 205000.0
# El precio predicho del inmueble seleccionado aleatoriamente es: 205416.08432598866
